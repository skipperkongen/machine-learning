# %%
"""
chord progression data
- Isophonics: http://isophonics.net/datasets
    Beatles: http://isophonics.net/content/reference-annotations-beatles
- Various pop songs: https://github.com/tmc323/Chord-Annotations/tree/master/RWC_Pop_Chords
"""
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/tmc323/Chord-Annotations/master/RWC_Pop_Chords/N001-M01-T01.lab', sep='\t')

# %%
df
# Out:
#        0.000    0.104               N
# 0      0.104    1.858          Ab:min
# 1      1.858    3.646          Gb:maj
# 2      3.646    5.387           E:maj
# 3      5.387    9.067         Gb:maj6
# 4      9.067   10.762          Eb:maj
# 5     10.762   12.527          Ab:min
# 6     12.527   14.199           E:maj
# 7     14.199   16.080           B:maj
# 8     16.080   17.868          Eb:maj
# 9     17.868   19.632          Ab:min
# 10    19.632   21.409           E:maj
# 11    21.409   22.303         Gb:maj6
# 12    22.303   23.197        Eb:maj/3
# 13    23.197   24.973          Ab:min
# 14    24.973   26.749          Gb:maj
# 15    26.749   28.444           F:dim
# 16    28.444   29.584           E:maj
# 17    29.584   30.302          Gb:maj
# 18    30.302   32.078          Ab:min
# 19    32.078   33.855          Gb:maj
# 20    33.855   35.631           F:dim
# 21    35.631   36.513           E:maj
# 22    36.513   37.407          Gb:maj
# 23    37.407   40.612          C:min7
# ...
